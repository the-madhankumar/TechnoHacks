# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
data = pd.read_csv("/kaggle/input/iris-dataset/iris.csv")

# %%
data.head()

# %%
sns.scatterplot(x=data["sepal_length"], y=data["species"])

# %%
sns.boxplot(y=data["sepal_length"], x=data["species"])

# %%
data.describe()

# %%
data.info()

# %%
data.isna().sum()

# %%
sns.pairplot(data=data)

# %%
sns.jointplot(data=data,x=data["species"],y=data["petal_length"])

# %%
from sklearn.model_selection import train_test_split

# %%
X = data.drop("species",axis =1)
y = data["species"]

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.41,random_state=0)

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
tree = DecisionTreeClassifier()

# %%
tree.fit(X_train,y_train)

# %%
predictions = tree.predict(X_test)

# %%
from sklearn.metrics import classification_report

# %%
print(classification_report(y_test, predictions))

# %%
from sklearn.metrics import confusion_matrix

# %%
print(confusion_matrix(y_test, predictions))
